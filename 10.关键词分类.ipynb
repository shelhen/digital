# %%
from utils.config import KeywordBy

keywords = KeywordBy["keywords"]
print(len(keywords))
keywords2 = []
# (4种数字技术+4种数字基础设施+3种数字化应用)
text = """
人工智能技术:人工智能、商业智能、图像理解、投资决策辅助系统、智能数据分析、智能机器人、机器学习、  深度学习、语义搜索、生物识别技术、人脸识别、语音识别、身份验证、自动驾驶、自然语言  处理、监督学习、机器翻译、OCR 技术、计算机视觉、机器视觉、机器人、智能问答、专家系统、  神经网络、学习算法、自动推理、无人驾驶
区块链技术:数字货币、智能合约、分布式计算、去中心化、比特币、联盟链、差分隐私技术、共识机制
云计算技术:内存计算、云计算、流计算、图计算、物联网、多方安全计算、类脑计算、绿色计算、认知计  算、融合架构、亿级并发、EB 级存储、信息物理系统、移动计算、云存储、边缘计算、云技术
大数据技术:大数据、数据挖掘、文本挖掘、数据可视化、异构数据、征信、增强现实、混合现实、虚拟现  实、文本抓取
人工智能基础设施:人工智能实验室、人工智能平台、人工智能设施、人工智能设备、人工智能基础设施、机器人、  人工智能系统、智能终端、智能信息系统 
云计算基础设施:云实验室、云平台、云系统、云设备、云设施、云终端、云社区、云技术系统
大数据基础设施:大数据实验室、大数据平台、大数据设施、大数据设备、大数据信息系统、大数据技术系统
广义数字基础设施:数字实验室、数字平台、数字社区、数字专利、数字网络、数字设施、数字设备、数字基础设  施、数字终端、数字信息系统、数字技术系统、3D 打印设备
技术创新:数字孪生、元宇宙、虚拟人、3D 打印、5G 技术、移动互联、移动互联网、工业互联网、数字技  术、纳米计算、智能规划、智能优化、智能穿戴
流程创新:智能制造、智能客服、智能营销、数字营销、无人零售、无人工厂、移动支付、第三方支付、  NFC 支付、人机交互、社交网络
业务创新:智慧农业、智能交通、智能医疗、智能家居、智能投顾、智能文旅、智能环保、智能电网、智能能源、互联网医疗、互联网金融、数字金融、Fintech、金融科技、量化金融、开放银行、网联、互联网+
""".strip()

text2 ="""
人工智能技术:人工智能, 商业智能, 图像理解, 投资决策辅助系统, 智能数据分析, 智能机器人, 机器学习, 深度学习, 语义搜索, 生物识别技术, 人脸识别, 语音识别, 身份验证, 自动驾驶, 自然语言处理, 智能故障诊断, 智能算法, 智能控制, 智能系统, 智能机, 智能技术, 智能物流, 智能仓储, 自动检测, 自动监控, 自动控制, 自动生产, 智能移动, 高端智能, 智能终端, 智能化, 交互, 智能生产, 智能管理, 智能工厂, 智能网联, 智能网, 智能设备, 智能文旅, 智能穿戴, 机器人, 人机交互, 无人零售, 智能客服, 智能营销, 智能环保, 智能能源, 智能电网, 智能医疗, 智能交通, 智能供应链, 智能投顾, 智能家居, 智能金融合约, 认知计算, 算法, 移动智能, 传感器, 虚拟制造, 物联网, 信息物理系统, 数控, 集成控制, 控制技术, 智能
区块链技术:区块链, 数字货币, 差分隐私技术, 分布式计算, 智能金融合约, 比特
云计算技术:内存计算, 云计算, 流计算, 图计算, 多方安全计算, 类脑计算, 绿色计算, 融合架构, 亿级并发, EB级存储, 云存储, 云服务, 云IT, 云生态, 虚拟化
大数据技术:大数据, 数据挖掘, 文本挖掘, 数据可视化, 异构数据, 征信, 增强现实, 混合现实, 虚拟现实, 数据分析, 数据管理, 数据共享, 数据处理, 数据安全, 数据流, 数据平台, 数据服务, 数据科学, 数据网络, 数字化数据管理, 公共数据, 应用数据
人工智能基础设施:人工智能设备, 智能终端, 智能信息系统
云计算基础设施:云平台
大数据基础设施:数据中心, 数据库, 关系型数据库
广义数字基础设施:数字终端, 数字网络, 数字设施, 数字设备, 数字技术, 数字电视, 数字通信
技术创新:工业互联网, 互联网技术, 移动互联, 移动互联网, 工业通信, 工业4.0, 数字创意, 数字技术, 网络设备, 网络设施, 网络服务, 网络覆盖, 联网, 网联, 互联网协议, 互联互通, 无线网络, 无线网, 无线电, 互联网移动, 高新技术, 关键技术, 新型工业化, 技术改造, 跨媒体, 互联网战略, 互联网模式, 技术开发, 产品开发, 编码, 互联网安全, 网络安全, 互联网生态, 网络化
流程创新:智能制造, 智能营销, 智能客服, 数字营销, 无人零售, 移动支付, NFC支付, 第三方支付, 人机交互, 商务智能, 自动化, 一体化, 集成化, 线上线下, 线上到线下, 线上, 网络零售, 电商, 电子商务移动互联网, 互联网商业模式, 直播, O2O, C2B, B2B, B2C, C2C, 互联网+, 互联网营销
业务创新:智慧农业, 智能交通, 智能医疗, 智能家居, 智能投顾, 智能文旅, 智能环保, 智能电网, 智能能源, 互联网医疗, 互联网金融, 数字金融, Fintech, 金融科技, 量化金融, 开放银行, 导航系统, 生态协同, 能源网
"""

kmap1 = {}
for item in text.split('\n'):
    name, value = item.split(':')
    value = [i.replace(' ', '') for i in  value.split('、') if i]
    # keywords2.extend(value)
    kmap1[name] = value

kmap2= {}
for item in text2.split('\n'):
    if not item:
        continue
    name, value = item.split(':')
    value = [i.replace(' ', '') for i in  value.split(', ') if i]
    kmap2[name] = value

keyword3 = []
count = 0
# 139个关键词，其中60个不属于283个关键词之中
for name in kmap1.keys():
    a = set(kmap1[name])
    a = a.union(set(kmap2[name]))
    # name, a
    # print(f"{name}:{','.join(list(a))},合计:{len(a)}个")
    keyword3.extend(list(a))
    count += len(a)
b = []
for k in keyword3:
    if k.replace(' ', '') not in keywords:
        b.append(k)
print(','.join(b))
# Out:
# 283
# 自动推理,专家系统,学习算法,OCR技术,计算机视觉,机器视觉,监督学习,无人驾驶,机器翻译,神经网络,智能问答,比特币,共识机制,去中心化,联盟链,智能合约,云技术,边缘计算,移动计算,文本抓取,人工智能基础设施,人工智能系统,人工智能设备,人工智能平台,智能信息系统,人工智能设施,人工智能实验室,云设备,云实验室,云社区,云技术系统,云终端,云系统,云设施,大数据信息系统,大数据设备,大数据实验室,大数据平台,大数据设施,大数据技术系统,3D打印设备,数字信息系统,数字实验室,数字专利,数字平台,数字社区,数字设施,数字基础设施,数字设备,数字技术系统,数字孪生,工业4.0,5G技术,智能规划,纳米计算,3D打印,智能优化,元宇宙,虚拟人,无人工厂,社交网络

# %%
# 将下列283个关键词划分为四种数字技术（人工智能技术、区块链技术、云计算技术、大数据技术），四种基础设施（人工智能基础设施、云计算基础设施、大数据基础设施、广义数字基础设施）和三种数字化应用（技术创新、流程创新、业务创新），参考案例：“人工智能技术:人工智能、商业智能、图像理解、投资决策辅助系统、智能数据分析、智能机器人、机器学习、  深度学习、语义搜索、生物识别技术、人脸识别、语音识别、身份验证、自动驾驶、自然语言  处理、监督学习、机器翻译、OCR 技术、计算机视觉、机器视觉、机器人、智能问答、专家系统、  神经网络、学习算法、自动推理、无人驾驶
# 区块链技术:数字货币、智能合约、分布式计算、去中心化、比特币、联盟链、差分隐私技术、共识机制
# 云计算技术:内存计算、云计算、流计算、图计算、物联网、多方安全计算、类脑计算、绿色计算、认知计  算、融合架构、亿级并发、EB 级存储、信息物理系统、移动计算、云存储、边缘计算、云技术
# 大数据技术:大数据、数据挖掘、文本挖掘、数据可视化、异构数据、征信、增强现实、混合现实、虚拟现  实、文本抓取
# 人工智能基础设施:人工智能实验室、人工智能平台、人工智能设施、人工智能设备、人工智能基础设施、机器人、  人工智能系统、智能终端、智能信息系统 
# 云计算基础设施:云实验室、云平台、云系统、云设备、云设施、云终端、云社区、云技术系统
# 大数据基础设施:大数据实验室、大数据平台、大数据设施、大数据设备、大数据信息系统、大数据技术系统
# 广义数字基础设施:数字实验室、数字平台、数字社区、数字专利、数字网络、数字设施、数字设备、数字基础设  施、数字终端、数字信息系统、数字技术系统、3D 打印设备
# 技术创新:数字孪生、元宇宙、虚拟人、3D 打印、5G 技术、移动互联、移动互联网、工业互联网、数字技  术、纳米计算、智能规划、智能优化、智能穿戴
# 流程创新:智能制造、智能客服、智能营销、数字营销、无人零售、无人工厂、移动支付、第三方支付、  NFC 支付、人机交互、社交网络
# 业务创新:智慧农业、智能交通、智能医疗、智能家居、智能投顾、智能文旅、智能环保、智能电网、智能能源、互联网医疗、互联网金融、数字金融、Fintech、金融科技、量化金融、开放银行、网联、互联网+”，要求，分类结果输出为 类别名称:keyword1,keyword2,keyword3,..., 总数
